# %%
# %sql
-- ============================================================
-- CAMADA: GOLD (BI)
-- TABELA: fct_pedidos
--
-- OBJETIVO:
-- Tabela fato central do BI, com granularidade de 1 pedido.
-- Base para KPIs, dashboards e análises exploratórias de churn.
--
-- FONTE:
-- workspace.olist_silver.pedidos_completos_silver
--
-- DESTINO:
-- workspace.olist_gold.fct_pedidos
-- ============================================================
CREATE SCHEMA IF NOT EXISTS workspace.olist_gold;

CREATE OR REPLACE VIEW workspace.olist_gold.fct_pedidos AS

SELECT *

FROM workspace.olist_silver.pedidos_completos_silver;
