# %% [markdown]
# # Camada Gold:
# ---

# %% [markdown]
# ## Objetivo:
#
# Criar espelho das views silver como base para consumo de BI.
#
# ### Views:
#
# `avaliacoes_silver`
#
# `clientes_silver`
#
# `geolocalizacao_silver`
#
# `itens_pedido_silver`
#
# `pagamentos_silver`
#
# `pedidos_silver`
#
# `produtos_silver`
#
# `vendedores_silver`
#
# ### Fonte:
#
# `workspace.olist_silver`
#
# ### Destino:
#
# `workspace.olist_gold`

# %%
# %sql
-- Garantindo a existência do schema:
CREATE SCHEMA IF NOT EXISTS workspace.olist_gold;

# %% [markdown]
# #### Avaliações:

# %%
# %sql
CREATE OR REPLACE VIEW workspace.olist_gold.avaliacoes AS
SELECT *
FROM workspace.olist_silver.avaliacoes_silver;

# %% [markdown]
# #### Clientes:

# %%
# %sql
CREATE OR REPLACE VIEW workspace.olist_gold.clientes AS
SELECT * 
FROM workspace.olist_silver.clientes_silver;

# %% [markdown]
# #### Geolocalização:

# %%
# %sql
CREATE OR REPLACE VIEW workspace.olist_gold.geolocalizacao AS
SELECT * 
FROM workspace.olist_silver.geolocalizacao_silver;

# %% [markdown]
# #### Itens do Pedido:

# %%
# %sql
CREATE OR REPLACE VIEW workspace.olist_gold.itens_pedido AS 
SELECT * 
FROM workspace.olist_silver.itens_pedido_silver;

# %% [markdown]
# #### Pagamentos:

# %%
# %sql
CREATE OR REPLACE VIEW workspace.olist_gold.pagamentos AS 
SELECT * 
FROM workspace.olist_silver.pagamentos_silver;

# %% [markdown]
# #### Pedidos:

# %%
# %sql
CREATE OR REPLACE VIEW workspace.olist_gold.pedidos AS 
SELECT * 
FROM workspace.olist_silver.pedidos_silver;

# %% [markdown]
# #### Produtos:

# %%
# %sql
CREATE OR REPLACE VIEW workspace.olist_gold.produtos AS 
SELECT * 
FROM workspace.olist_silver.produtos_silver;

# %% [markdown]
# #### Vendedores:

# %%
# %sql
CREATE OR REPLACE VIEW workspace.olist_gold.vendedores AS
SELECT * 
FROM workspace.olist_silver.vendedores_silver;
